# %%
from pathlib import Path
import os
import pandas as pd

notebook_dir = Path(r"c:\Users\kaidc\Documents\Github\quadruped_design\testing\data")
os.chdir(notebook_dir)

# %% [markdown]
# # Load Data

# %% [markdown]
# ## FK Tests

# %% [markdown]
# ### 1-26

# %%
# # FK Test 1-26
# fk_1_26_hip_roll_df = pd.read_csv("FKTest_1-26/Hip Roll.csv")
# fk_1_26_hip_pitch_df = pd.read_csv("FKTest_1-26/Hip Pitch.csv")
# fk_1_26_knee_pitch_df = pd.read_csv("FKTest_1-26/Knee Pitch.csv")
# fk_1_26_torques_df = pd.read_csv("FKTest_1-26/Motor Effort.csv")

# %% [markdown]
# ### 1-27

# %%
# # FK Test 1 (1-27)
# fk_1_hip_roll_df = pd.read_csv("FKTests-1-27/Test1/Hip Roll.csv")
# fk_1_hip_pitch_df = pd.read_csv("FKTests-1-27/Test1/Hip Pitch.csv")
# fk_1_knee_pitch_df = pd.read_csv("FKTests-1-27/Test1/Knee Pitch.csv")
# fk_1_torques_df = pd.read_csv("FKTests-1-27/Test1/Motor Effort.csv")

# %%
# # FK Test 2 (1-27)
# fk_2_hip_roll_df = pd.read_csv("FKTests-1-27/Test2/Hip Roll.csv")
# fk_2_hip_pitch_df = pd.read_csv("FKTests-1-27/Test2/Hip Pitch.csv")
# fk_2_knee_pitch_df = pd.read_csv("FKTests-1-27/Test2/Knee Pitch.csv")
# fk_2_torques_df = pd.read_csv("FKTests-1-27/Test2/Motor Effort.csv")

# %%
# # FK Test 3 (1-27)
# fk_3_hip_roll_df = pd.read_csv("FKTests-1-27/Test3/Hip Roll.csv")
# fk_3_hip_pitch_df = pd.read_csv("FKTests-1-27/Test3/Hip Pitch.csv")
# fk_3_knee_pitch_df = pd.read_csv("FKTests-1-27/Test3/Knee Pitch.csv")
# fk_3_torques_df = pd.read_csv("FKTests-1-27/Test3/Motor Effort.csv")

# %% [markdown]
# ## IK Tests

# %% [markdown]
# ### 1-27

# %%
# # IK Test 1 (1-27)
# ik_crouched_hip_roll_df = pd.read_csv("IKTests-1-27/crouched_stance/Hip Roll.csv")
# ik_crouched_hip_pitch_df = pd.read_csv("IKTests-1-27/crouched_stance/Hip Pitch.csv")
# ik_crouched_knee_pitch_df = pd.read_csv("IKTests-1-27/crouched_stance/Knee Pitch.csv")
# ik_crouched_torques_df = pd.read_csv("IKTests-1-27/crouched_stance/Motor Effort.csv")

# %%
# # IK Test 2 (1-27)
# ik_extended_hip_roll_df = pd.read_csv("IKTests-1-27/extended_stance/Hip Roll.csv")
# ik_extended_hip_pitch_df = pd.read_csv("IKTests-1-27/extended_stance/Hip Pitch.csv")
# ik_extended_knee_pitch_df = pd.read_csv("IKTests-1-27/extended_stance/Knee Pitch.csv")
# ik_extended_torques_df = pd.read_csv("IKTests-1-27/extended_stance/Motor Effort.csv")

# %%
# # IK Test 3 (1-27)
# ik_standard_hip_roll_df = pd.read_csv("IKTests-1-27/standard-stance/Hip Roll.csv")
# ik_standard_hip_pitch_df = pd.read_csv("IKTests-1-27/standard-stance/Hip Pitch.csv")
# ik_standard_knee_pitch_df = pd.read_csv("IKTests-1-27/standard-stance/Knee Pitch.csv")
# ik_standard_torques_df = pd.read_csv("IKTests-1-27/standard-stance/Motor Effort.csv")

# %% [markdown]
# ## Impedance Tests

# %% [markdown]
# ### 1-27

# %%
# # Impedance Test 4 (1-27)
# impedance_hip_roll_df = pd.read_csv("ImpTests-1-27/Test4/Hip Roll.csv")
# impedance_hip_pitch_df = pd.read_csv("ImpTests-1-27/Test4/Hip Pitch.csv")
# impedance_knee_pitch_df = pd.read_csv("ImpTests-1-27/Test4/Knee Pitch.csv")
# impedance_torques_df = pd.read_csv("ImpTests-1-27/Test4/Motor Effort.csv")

# %% [markdown]
# ## Impact Tests

# %% [markdown]
# ### 12 inch

# %%
# # Impact 12 inches - Test 1  (1-27)
# impact12_hip_roll_df = pd.read_csv("ImpactTests/drop12/Hip Roll.csv")
# impact12_hip_pitch_df = pd.read_csv("ImpactTests/drop12/Hip Pitch.csv")
# impact12_knee_pitch_df = pd.read_csv("ImpactTests/drop12/Knee Pitch.csv")
# impact12_torques_df = pd.read_csv("ImpactTests/drop12/Motor Effort.csv")

# %%
# # Impact 12 inches - Test 2  (1-27)
# impact12_again_hip_roll_df = pd.read_csv("ImpactTests/drop12_again/Hip Roll.csv")
# impact12_again_hip_pitch_df = pd.read_csv("ImpactTests/drop12_again/Hip Pitch.csv")
# impact12_again_knee_pitch_df = pd.read_csv("ImpactTests/drop12_again/Knee Pitch.csv")
# impact12_again_torques_df = pd.read_csv("ImpactTests/drop12_again/Motor Effort.csv")

# %% [markdown]
# # Helper Functions

# %%
topics = [
    "/joint_states.position[0]",
    "/joint_states.position[1]",
    "/joint_states.position[2]",
    "/joint_states.velocity[0]",
    "/joint_states.velocity[1]",
    "/joint_states.velocity[2]",
    "/static_joints_controller/commands.data[0]",
    "/static_joints_controller/commands.data[1]",
    "/static_joints_controller/commands.data[2]",
    "/joint_states.position[0]",
    "/joint_states.position[1]",
    "/joint_states.position[2]",
    "/joint_states.effort[0]",
    "/joint_states.effort[1]",
    "/joint_states.effort[2]",
]

def align_topics(df, topics=None, time_col="elapsed time", interpolate=False, fill_method="ffill"):
    """Pivot topics into columns and optionally fill/interpolate missing values."""
    if "timestamp" not in df.columns:
        raise ValueError("DataFrame must include a 'timestamp' column.")

    ts = pd.to_numeric(df["timestamp"], errors="coerce")
    if ts.isna().all():
        raise ValueError("All timestamps are NaN after conversion.")
    t0 = ts.min()

    work = df.copy()
    work["elapsed time"] = ts - t0

    if topics is not None:
        work = work[work["topic"].isin(topics)]

    if time_col not in work.columns:
        raise ValueError(f"Missing time column: {time_col}")

    wide = (
        work.pivot_table(
            index=time_col,
            columns="topic",
            values="value",
            aggfunc="first",
        )
        .sort_index()
    )

    if fill_method:
        wide = wide.fillna(method=fill_method)

    if interpolate:
        wide = wide.interpolate(method="linear", limit_direction="both")

    wide = wide.reset_index()

    # Ensure elapsed time is present even if aligning on timestamp
    if time_col != "elapsed time":
        wide["elapsed time"] = pd.to_numeric(wide[time_col], errors="coerce") - t0

    wide.columns.name = None
    return wide

# %%
def export_data(dfs, out_dir, filenames=None):
    """Export a list of DataFrames to CSV files in out_dir."""
    from pathlib import Path

    out_dir = Path(out_dir)
    out_dir.mkdir(parents=True, exist_ok=True)

    if filenames is not None and len(filenames) != len(dfs):
        raise ValueError("filenames length must match dfs length.")

    for i, df in enumerate(dfs):
        name = filenames[i] if filenames is not None else f"df_{i}.csv"
        df.to_csv(out_dir / name, index=False)

# %%
def effort2current(effort, motor_constant=0.38, effort_cols=None):
    """Convert motor effort (Nm) to current (A) using motor constant (Nm/A)."""
    import pandas as pd

    if motor_constant == 0:
        raise ValueError("motor_constant must be non-zero.")

    # DataFrame: scale effort columns in-place copy
    if isinstance(effort, pd.DataFrame):
        out = effort.copy()
        if effort_cols is None:
            effort_cols = [c for c in out.columns if c.startswith("/joint_states.effort[")]
        if not effort_cols:
            raise ValueError("No effort columns found to scale.")
        out[effort_cols] = abs(out[effort_cols] / motor_constant)
        return out

    # Series/array/scalar
    return abs(effort / motor_constant)

# %% [markdown]
# # Export Data

# %% [markdown]
# ## FK Tests

# %% [markdown]
# ### 1-26

# %%
# # FK Test 1-26 data cleaned and aligned
# hip_roll_aligned = align_topics(fk_1_26_hip_roll_df, topics=topics, fill_method="ffill")
# hip_pitch_aligned = align_topics(fk_1_26_hip_pitch_df, topics=topics, fill_method="ffill")
# knee_pitch_aligned = align_topics(fk_1_26_knee_pitch_df, topics=topics, fill_method="ffill")
# torques_aligned = align_topics(fk_1_26_torques_df, topics=topics, fill_method=None)
# torques_current = effort2current(torques_aligned)

# export_data(dfs, "FKTest_1-26", filenames=names)

# %% [markdown]
# ### 1-27

# %%
# FK Test 1 1-27 data cleaned and aligned
# hip_roll_aligned = align_topics(fk_1_hip_roll_df, topics=topics, fill_method="ffill")
# hip_pitch_aligned = align_topics(fk_1_hip_pitch_df, topics=topics, fill_method="ffill")
# knee_pitch_aligned = align_topics(fk_1_knee_pitch_df, topics=topics, fill_method="ffill")
# torques_aligned = align_topics(fk_1_torques_df, topics=topics, fill_method=None)
# torques_current = effort2current(torques_aligned)   

# dfs = [
#     hip_roll_aligned,
#     hip_pitch_aligned,
#     knee_pitch_aligned,
#     torques_aligned,
#     torques_current,
# ]

# names = [
#     "aligned_hip_roll.csv",
#     "aligned_hip_pitch.csv",
#     "aligned_knee_pitch.csv",
#     "aligned_torques.csv",
#     "aligned_current.csv",
# ]
# export_data(dfs, "FKTests-1-27/Test1/Processed", filenames=names)

# %%
# # FK Test 2 1-27 data cleaned and aligned
# hip_roll_aligned = align_topics(fk_2_hip_roll_df, topics=topics, fill_method="ffill")
# hip_pitch_aligned = align_topics(fk_2_hip_pitch_df, topics=topics, fill_method="ffill")
# knee_pitch_aligned = align_topics(fk_2_knee_pitch_df, topics=topics, fill_method="ffill")
# torques_aligned = align_topics(fk_2_torques_df, topics=topics, fill_method=None)
# torques_current = effort2current(torques_aligned)

# dfs = [
#     hip_roll_aligned,
#     hip_pitch_aligned,
#     knee_pitch_aligned,
#     torques_aligned,
#     torques_current,
# ]

# names = [
#     "aligned_hip_roll.csv",
#     "aligned_hip_pitch.csv",
#     "aligned_knee_pitch.csv",
#     "aligned_torques.csv",
#     "aligned_current.csv",
# ]
# export_data(dfs, "FKTests-1-27/Test2/Processed", filenames=names)

# %%
# FK Test 3 1-27 data cleaned and aligned
hip_roll_aligned = align_topics(fk_3_hip_roll_df, topics=topics, fill_method="ffill")
hip_pitch_aligned = align_topics(fk_3_hip_pitch_df, topics=topics, fill_method="ffill")
knee_pitch_aligned = align_topics(fk_3_knee_pitch_df, topics=topics, fill_method="ffill")
torques_aligned = align_topics(fk_3_torques_df, topics=topics, fill_method=None)
torques_current = effort2current(torques_aligned)   

dfs = [
    hip_roll_aligned,
    hip_pitch_aligned,
    knee_pitch_aligned,
    torques_aligned,
    torques_current,
]

names = [
    "aligned_hip_roll.csv",
    "aligned_hip_pitch.csv",
    "aligned_knee_pitch.csv",
    "aligned_torques.csv",
    "aligned_current.csv",
]
export_data(dfs, "FKTests-1-27/Test3/Processed", filenames=names)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[18], line 2
#       1 # FK Test 3 1-27 data cleaned and aligned
# ----> 2 hip_roll_aligned = align_topics(fk_3_hip_roll_df, topics=topics, fill_method="ffill")
#       3 hip_pitch_aligned = align_topics(fk_3_hip_pitch_df, topics=topics, fill_method="ffill")
#       4 knee_pitch_aligned = align_topics(fk_3_knee_pitch_df, topics=topics, fill_method="ffill")
#
# NameError: name 'fk_3_hip_roll_df' is not defined

# %% [markdown]
# ## IK Tests

# %% [markdown]
# ### 1-27

# %%
# # IK Test 1 1-27 data cleaned and aligned
# hip_roll_aligned = align_topics(ik_crouched_hip_roll_df, topics=topics, fill_method="ffill")
# hip_pitch_aligned = align_topics(ik_crouched_hip_pitch_df, topics=topics, fill_method="ffill")
# knee_pitch_aligned = align_topics(ik_crouched_knee_pitch_df, topics=topics, fill_method="ffill")
# torques_aligned = align_topics(ik_crouched_torques_df, topics=topics, fill_method=None)
# torques_current = effort2current(torques_aligned)   

# dfs = [
#     hip_roll_aligned,
#     hip_pitch_aligned,
#     knee_pitch_aligned,
#     torques_aligned,
#     torques_current,
# ]

# names = [
#     "aligned_hip_roll.csv",
#     "aligned_hip_pitch.csv",
#     "aligned_knee_pitch.csv",
#     "aligned_torques.csv",
#     "aligned_current.csv",
# ]
# export_data(dfs, "IKTests-1-27/crouched_stance/Processed", filenames=names)
# Out:
# C:\Users\kaidc\AppData\Local\Temp\ipykernel_24904\3497243746.py:46: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   wide = wide.fillna(method=fill_method)
# C:\Users\kaidc\AppData\Local\Temp\ipykernel_24904\3497243746.py:46: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   wide = wide.fillna(method=fill_method)
# C:\Users\kaidc\AppData\Local\Temp\ipykernel_24904\3497243746.py:46: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   wide = wide.fillna(method=fill_method)

# %%
# # # IK Test 2 1-27 data cleaned and aligned
# hip_roll_aligned = align_topics(ik_extended_hip_roll_df, topics=topics, fill_method="ffill")
# hip_pitch_aligned = align_topics(ik_extended_hip_pitch_df, topics=topics, fill_method="ffill")
# knee_pitch_aligned = align_topics(ik_extended_knee_pitch_df, topics=topics, fill_method="ffill")
# torques_aligned = align_topics(ik_extended_torques_df, topics=topics, fill_method=None)
# torques_current = effort2current(torques_aligned)   

# dfs = [
#     hip_roll_aligned,
#     hip_pitch_aligned,
#     knee_pitch_aligned,
#     torques_aligned,
#     torques_current,
# ]

# names = [
#     "aligned_hip_roll.csv",
#     "aligned_hip_pitch.csv",
#     "aligned_knee_pitch.csv",
#     "aligned_torques.csv",
#     "aligned_current.csv",
# ]
# export_data(dfs, "IKTests-1-27/extended_stance/Processed", filenames=names)
# Out:
# C:\Users\kaidc\AppData\Local\Temp\ipykernel_24904\3497243746.py:46: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   wide = wide.fillna(method=fill_method)
# C:\Users\kaidc\AppData\Local\Temp\ipykernel_24904\3497243746.py:46: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   wide = wide.fillna(method=fill_method)
# C:\Users\kaidc\AppData\Local\Temp\ipykernel_24904\3497243746.py:46: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   wide = wide.fillna(method=fill_method)

# %%
# # # IK Test 3 1-27 data cleaned and aligned
# hip_roll_aligned = align_topics(ik_standard_hip_roll_df, topics=topics, fill_method="ffill")
# hip_pitch_aligned = align_topics(ik_standard_hip_pitch_df, topics=topics, fill_method="ffill")
# knee_pitch_aligned = align_topics(ik_standard_knee_pitch_df, topics=topics, fill_method="ffill")
# torques_aligned = align_topics(ik_standard_torques_df, topics=topics, fill_method=None)
# torques_current = effort2current(torques_aligned)   

# dfs = [
#     hip_roll_aligned,
#     hip_pitch_aligned,
#     knee_pitch_aligned,
#     torques_aligned,
#     torques_current,
# ]

# names = [
#     "aligned_hip_roll.csv",
#     "aligned_hip_pitch.csv",
#     "aligned_knee_pitch.csv",
#     "aligned_torques.csv",
#     "aligned_current.csv",
# ]
# export_data(dfs, "IKTests-1-27/standard-stance/Processed", filenames=names)
# Out:
# C:\Users\kaidc\AppData\Local\Temp\ipykernel_24904\3497243746.py:46: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   wide = wide.fillna(method=fill_method)
# C:\Users\kaidc\AppData\Local\Temp\ipykernel_24904\3497243746.py:46: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   wide = wide.fillna(method=fill_method)
# C:\Users\kaidc\AppData\Local\Temp\ipykernel_24904\3497243746.py:46: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   wide = wide.fillna(method=fill_method)

# %% [markdown]
# ## Impedance Tests

# %% [markdown]
# ### 1-27

# %%
# # Impedance Test 4 1-27 data cleaned and aligned
# hip_roll_aligned = align_topics(impedance_hip_roll_df, topics=topics, fill_method="ffill")
# hip_pitch_aligned = align_topics(impedance_hip_pitch_df, topics=topics, fill_method="ffill")
# knee_pitch_aligned = align_topics(impedance_knee_pitch_df, topics=topics, fill_method="ffill")
# torques_aligned = align_topics(impedance_torques_df, topics=topics, fill_method=None)
# torques_current = effort2current(torques_aligned)   

# dfs = [
#     hip_roll_aligned,
#     hip_pitch_aligned,
#     knee_pitch_aligned,
#     torques_aligned,
#     torques_current,
# ]

# names = [
#     "aligned_hip_roll.csv",
#     "aligned_hip_pitch.csv",
#     "aligned_knee_pitch.csv",
#     "aligned_torques.csv",
#     "aligned_current.csv",
# ]
# export_data(dfs, "ImpTests-1-27/Test4/Processed", filenames=names)
# Out:
# C:\Users\kaidc\AppData\Local\Temp\ipykernel_24904\3865213755.py:49: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   wide = wide.fillna(method=fill_method)
# C:\Users\kaidc\AppData\Local\Temp\ipykernel_24904\3865213755.py:49: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   wide = wide.fillna(method=fill_method)
# C:\Users\kaidc\AppData\Local\Temp\ipykernel_24904\3865213755.py:49: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   wide = wide.fillna(method=fill_method)

# %% [markdown]
# ## Impact Tests

# %% [markdown]
# ### 12 inch test 1

# %%
# # Impact 12 inches - Test 1 -  1-27 data cleaned and aligned
# hip_roll_aligned = align_topics(impact12_hip_roll_df, topics=topics, fill_method="ffill")
# hip_pitch_aligned = align_topics(impact12_hip_pitch_df, topics=topics, fill_method="ffill")
# knee_pitch_aligned = align_topics(impact12_knee_pitch_df, topics=topics, fill_method="ffill")
# torques_aligned = align_topics(impact12_torques_df, topics=topics, fill_method=None)
# torques_current = effort2current(torques_aligned)   

# dfs = [
#     hip_roll_aligned,
#     hip_pitch_aligned,
#     knee_pitch_aligned,
#     torques_aligned,
#     torques_current,
# ]

# names = [
#     "aligned_hip_roll.csv",
#     "aligned_hip_pitch.csv",
#     "aligned_knee_pitch.csv",
#     "aligned_torques.csv",
#     "aligned_current.csv",
# ]
# export_data(dfs, "ImpactTests/drop12/Processed", filenames=names)
# Out:
# C:\Users\kaidc\AppData\Local\Temp\ipykernel_33608\3865213755.py:49: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   wide = wide.fillna(method=fill_method)
# C:\Users\kaidc\AppData\Local\Temp\ipykernel_33608\3865213755.py:49: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   wide = wide.fillna(method=fill_method)
# C:\Users\kaidc\AppData\Local\Temp\ipykernel_33608\3865213755.py:49: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   wide = wide.fillna(method=fill_method)

# %%
# # Impact 12 inches - Test 1 -  1-27 data cleaned and aligned
# hip_roll_aligned = align_topics(impact12_again_hip_roll_df, topics=topics, fill_method="ffill")
# hip_pitch_aligned = align_topics(impact12_again_hip_pitch_df, topics=topics, fill_method="ffill")
# knee_pitch_aligned = align_topics(impact12_again_knee_pitch_df, topics=topics, fill_method="ffill")
# torques_aligned = align_topics(impact12_again_torques_df, topics=topics, fill_method=None)
# torques_current = effort2current(torques_aligned)   

# dfs = [
#     hip_roll_aligned,
#     hip_pitch_aligned,
#     knee_pitch_aligned,
#     torques_aligned,
#     torques_current,
# ]

# names = [
#     "aligned_hip_roll.csv",
#     "aligned_hip_pitch.csv",
#     "aligned_knee_pitch.csv",
#     "aligned_torques.csv",
#     "aligned_current.csv",
# ]
# export_data(dfs, "ImpactTests/drop12_again/Processed", filenames=names)
# Out:
# C:\Users\kaidc\AppData\Local\Temp\ipykernel_33608\3865213755.py:49: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   wide = wide.fillna(method=fill_method)
# C:\Users\kaidc\AppData\Local\Temp\ipykernel_33608\3865213755.py:49: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   wide = wide.fillna(method=fill_method)
# C:\Users\kaidc\AppData\Local\Temp\ipykernel_33608\3865213755.py:49: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   wide = wide.fillna(method=fill_method)

# %% [markdown]
# ## All Test Currents

# %% [markdown]
# ### No-load Tests

# %%
fk_1_torques_df = pd.read_csv("FKTests/Test1/Motor Effort.csv")
fk_2_torques_df = pd.read_csv("FKTests/Test2/Motor Effort.csv")
fk_3_torques_df = pd.read_csv("FKTests/Test3/Motor Effort.csv")

ik_crouched_torques_df = pd.read_csv("IKTests/crouched_stance/Motor Effort.csv")
ik_extended_torques_df = pd.read_csv("IKTests/extended_stance/Motor Effort.csv")
ik_standard_torques_df = pd.read_csv("IKTests/standard-stance/Motor Effort.csv")

# %%
fk1_aligned_df = align_topics(fk_1_torques_df, topics=topics, fill_method=None)
fk2_aligned_df = align_topics(fk_2_torques_df, topics=topics, fill_method=None)
fk3_aligned_df = align_topics(fk_3_torques_df, topics=topics, fill_method=None)

ik_crouched_aligned_df = align_topics(ik_crouched_torques_df, topics=topics, fill_method=None)
ik_extended_aligned_df = align_topics(ik_extended_torques_df, topics=topics, fill_method=None)
ik_standard_aligned_df = align_topics(ik_standard_torques_df, topics=topics, fill_method=None)

fk1_aligned_df = effort2current(fk1_aligned_df)
fk2_aligned_df = effort2current(fk2_aligned_df)
fk3_aligned_df = effort2current(fk3_aligned_df)
ik_crouched_aligned_df = effort2current(ik_crouched_aligned_df)
ik_extended_aligned_df = effort2current(ik_extended_aligned_df)
ik_standard_aligned_df = effort2current(ik_standard_aligned_df)

dfs = [
    fk1_aligned_df,
    fk2_aligned_df,
    fk3_aligned_df,
    ik_crouched_aligned_df,
    ik_extended_aligned_df,
    ik_standard_aligned_df,
]

names = [
    "aligned_fk1.csv",
    "aligned_fk2.csv",
    "aligned_fk3.csv",
    "aligned_crouched.csv",
    "aligned_extended.csv",
    "aligned_standard.csv",
]

export_data(dfs, "CurrentTests/No_load", filenames=names)

# %% [markdown]
# ### Dynamic Tests

# %%
imped_1_torques_df = pd.read_csv("ImpTests/Test1/Motor Effort.csv")
imped_2_torques_df = pd.read_csv("ImpTests/Test2/Motor Effort.csv")
imped_3_torques_df = pd.read_csv("ImpTests/Test3/Motor Effort.csv")
imped_4_torques_df = pd.read_csv("ImpTests/Test4/Motor Effort.csv")

impact_3_torques_df = pd.read_csv("ImpactTests/drop3/Motor Effort.csv")
impact_6_torques_df = pd.read_csv("ImpactTests/drop6/Motor Effort.csv")
impact_9_torques_df = pd.read_csv("ImpactTests/drop9/Motor Effort.csv")
impact_12_torques_df = pd.read_csv("ImpactTests/drop12/Motor Effort.csv")
impact_12again_torques_df = pd.read_csv("ImpactTests/drop12_again/Motor Effort.csv")

# %%
imped1_aligned_df = align_topics(imped_1_torques_df, topics=topics, fill_method=None)
imped2_aligned_df = align_topics(imped_2_torques_df, topics=topics, fill_method=None)
imped3_aligned_df = align_topics(imped_3_torques_df, topics=topics, fill_method=None)

impact3_aligned_df = align_topics(impact_3_torques_df, topics=topics, fill_method=None)
impact6_aligned_df = align_topics(impact_6_torques_df, topics=topics, fill_method=None)
impact9_aligned_df = align_topics(impact_9_torques_df, topics=topics, fill_method=None)
impact12_aligned_df = align_topics(impact_12_torques_df, topics=topics, fill_method=None)
impact12again_aligned_df = align_topics(impact_12again_torques_df, topics=topics, fill_method=None)

imped1_aligned_df = effort2current(imped1_aligned_df)
imped2_aligned_df = effort2current(imped2_aligned_df)
imped3_aligned_df = effort2current(imped3_aligned_df)
impact3_aligned_df = effort2current(impact3_aligned_df)
impact6_aligned_df = effort2current(impact6_aligned_df)
impact9_aligned_df = effort2current(impact9_aligned_df)
impact12_aligned_df = effort2current(impact12_aligned_df)
impact12again_aligned_df = effort2current(impact12again_aligned_df)

dfs = [
    imped1_aligned_df,
    imped2_aligned_df,  
    imped3_aligned_df,
    impact3_aligned_df,
    impact6_aligned_df,
    impact9_aligned_df,
    impact12_aligned_df,
    impact12again_aligned_df,
]

names = [
    "aligned_imped1.csv",
    "aligned_imped2.csv",
    "aligned_imped3.csv",
    "aligned_impact3.csv",
    "aligned_impact6.csv",
    "aligned_impact9.csv",
    "aligned_impact12.csv",
    "aligned_impact12again.csv",
]

export_data(dfs, "CurrentTests/Dynamic", filenames=names)
